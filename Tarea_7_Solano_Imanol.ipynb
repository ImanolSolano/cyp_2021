# %% [markdown]
# <a href="https://colab.research.google.com/github/ImanolSolano/cyp_2021/blob/main/Tarea_7_Solano_Imanol.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
paises=input("Ingresa el total de paises del sur, centro y norteamerica: ")
TPS=0
TPC=0
TPN=0
if 1 <= TPS <= 30 and 1 <= TPC <= 30 and 1 >= TPN >= 30:
  sudamerica=input("Ingresa el número de paises de Sudamerica: ")
  i=1
  while i <= TPS:
    print(f"Ingresa el nombre del país {i}: ")
    sur[i]
    i=i+1
  else: 
    centro_america=input("Ingresa los nombres de los paises de centroamerica: ")
    i=1
    while i <= TPC:
      print(f"Ingresa el nombre del país {i}")
      centro[i]
      i=i+1
    else: 
      norteamerica=input("Ingresa los nombres de los paises de Norteamerica: ")
      i=1
      while i <= TPN:
        print(f"Ingresa el nombre del pais {i}")
        norte[i]
        i=i+1
      else:
        PS=1
        PN=1
        PC=1
        PA=0
        while PS <= TPS and PC <= TPC and PN <= TPN:
          PA=PA+1
          if sur[PS]<centro[PC] and sur[PS]<norte[PN]:
            america[PA]=sur[PS]
            PS=PS+1
          else:
            if centro[PC]<norte[PN]:
              america[PA]=centro[PC]
              PC=PC+1
            else:
              america[PA]=norte[PN]
              PN=PN+1
        else: 
          while PS <= TPS and PC <= TPC:
            PA=PA+1
            if sur[PS] < centro[PS]:
              america[PA]=sur[PS]
              PS=PS+1
            else:
              america[PA]=centro[PC]
              PC=PC+1
          else:
            while PS <= TPS and PN <= TPN:
              PA=PA+1
              if sur[PS] < norte[PN]:
                america[PA]=sur[PS]
                PS=PS+1
              else: 
                america[PA]=norte[PN]
                PN=PN+1
            else:
              while PC <= TPC and PN <= TPN:
                PA=PA+1
                if centro[PC] < norte[PN]: 
                  america[PA]=centro[PC]
                  PC=PC+1
                else:
                  america[PA]=norte[PN]
                  PN=PN+1
              else:
                while PS <= TPS:
                  PA=PA+1
                  america[PA]=sur[PS]
                  PS=PS+1
                else: 
                  while PC <= TPC:
                    PA=PA+1
                    america[PA]=centro[PC]
                    PC=PC+1
                  else:
                    while PN <= TPN:
                      PA=PA+1
                      america[PA]=norte[PN]
                      PN=PN+1
                    else:
                      print("Arreglo América")
                      i=1
                      while i <= PA:
                        america[i]
                        i=i+1
else:
  print("Verifique el número de países ingresados. :)")
